# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
athlete_events = "athlete_events.csv.zip"

athlete_data = pd.read_csv(athlete_events, index_col=0)

# %%
# ad = athlete_data.pd.DataFrame

# %%
athlete_data.head()
# Out:
#                         Name Sex   Age  Height  Weight            Team  NOC  \
# ID
# 1                  A Dijiang   M  24.0   180.0    80.0           China  CHN
# 2                   A Lamusi   M  23.0   170.0    60.0           China  CHN
# 3        Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark  DEN
# 4       Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden  DEN
# 5   Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands  NED
#
#           Games  Year  Season       City          Sport  \
# ID
# 1   1992 Summer  1992  Summer  Barcelona     Basketball
# 2   2012 Summer  2012  Summer     London           Judo
# 3   1920 Summer  1920  Summer  Antwerpen       Football
# 4   1900 Summer  1900  Summer      Paris     Tug-Of-War
# 5   1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                                Event Medal
# ID
# 1        Basketball Men's Basketball   NaN
# 2       Judo Men's Extra-Lightweight   NaN
# ...

# %%
x = athlete_data.dropna(subset = ['Medal'])
x = athlete_data.dropna(subset = ['Height'])
x = athlete_data.dropna(subset = ['Weight'])

# %%
# Sorting data by year from 1896 to 2016
dataByYear= athlete_data.sort_values("Year")
dataByYear.head()
# Out:
#                                Name Sex   Age  Height  Weight     Team  \
# ID
# 107607  Fritz Richard Gustav Schuft   M  19.0     NaN     NaN  Germany
# 122526      Pierre Alexandre Tuffri   M  19.0     NaN     NaN   France
# 122526      Pierre Alexandre Tuffri   M  19.0     NaN     NaN   France
# 12563     Conrad Helmut Fritz Bcker   M  25.0     NaN     NaN  Germany
# 12563     Conrad Helmut Fritz Bcker   M  25.0     NaN     NaN  Germany
#
#        Country        Games  Year  Season    City       Sport  \
# ID
# 107607     GER  1896 Summer  1896  Summer  Athina  Gymnastics
# 122526     FRA  1896 Summer  1896  Summer  Athina   Athletics
# 122526     FRA  1896 Summer  1896  Summer  Athina   Athletics
# 12563      GER  1896 Summer  1896  Summer  Athina  Gymnastics
# 12563      GER  1896 Summer  1896  Summer  Athina  Gymnastics
#
#                                    Event   Medal
# ID
# 107607  Gymnastics Men's Pommelled Horse     NaN
# 122526       Athletics Men's Triple Jump  Silver
# ...

# %%
# Summer Olympic Data
data_summer = dataByYear[dataByYear.Season == "Summer"]
data_summer.head()
# Out:
#                                Name Sex   Age  Height  Weight     Team  \
# ID
# 107607  Fritz Richard Gustav Schuft   M  19.0     NaN     NaN  Germany
# 122526      Pierre Alexandre Tuffri   M  19.0     NaN     NaN   France
# 122526      Pierre Alexandre Tuffri   M  19.0     NaN     NaN   France
# 12563     Conrad Helmut Fritz Bcker   M  25.0     NaN     NaN  Germany
# 12563     Conrad Helmut Fritz Bcker   M  25.0     NaN     NaN  Germany
#
#        Country        Games  Year  Season    City       Sport  \
# ID
# 107607     GER  1896 Summer  1896  Summer  Athina  Gymnastics
# 122526     FRA  1896 Summer  1896  Summer  Athina   Athletics
# 122526     FRA  1896 Summer  1896  Summer  Athina   Athletics
# 12563      GER  1896 Summer  1896  Summer  Athina  Gymnastics
# 12563      GER  1896 Summer  1896  Summer  Athina  Gymnastics
#
#                                    Event   Medal
# ID
# 107607  Gymnastics Men's Pommelled Horse     NaN
# 122526       Athletics Men's Triple Jump  Silver
# ...

# %%
# Winter Olympic Data
data_winter = dataByYear[dataByYear.Season == "Winter"]
data_winter.head()
# Out:
#                                 Name Sex   Age  Height  Weight           Team  \
# ID
# 105349             Jonas Elis Sandin   M  22.0     NaN     NaN         Sweden
# 40532   Jules Alexandre Girard-Bille   M   NaN     NaN     NaN    Switzerland
# 83350      Duncan Brown "Dunc" Munro   M  23.0   173.0    86.0         Canada
# 74134   George Herbert Leigh Mallory   M  37.0     NaN     NaN  Great Britain
# 106776               Eduard Scherrer   M  33.0     NaN     NaN  Switzerland-1
#
#        Country        Games  Year  Season      City                 Sport  \
# ID
# 105349     SWE  1924 Winter  1924  Winter  Chamonix  Cross Country Skiing
# 40532      SUI  1924 Winter  1924  Winter  Chamonix       Nordic Combined
# 83350      CAN  1924 Winter  1924  Winter  Chamonix            Ice Hockey
# 74134      GBR  1924 Winter  1924  Winter  Chamonix              Alpinism
# 106776     SUI  1924 Winter  1924  Winter  Chamonix             Bobsleigh
#
# ...

# %%
data2 = athlete_data.dropna(subset=['Medal'])
data2.head()
# Out:
#                         Name Sex   Age  Height  Weight            Team  \
# ID
# 4       Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0         Finland
# 17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
#
#    Country        Games  Year  Season       City       Sport  \
# ID
# 4      DEN  1900 Summer  1900  Summer      Paris  Tug-Of-War
# 15     FIN  1920 Summer  1920  Summer  Antwerpen    Swimming
# 15     FIN  1920 Summer  1920  Summer  Antwerpen    Swimming
# 16     FIN  2014 Winter  2014  Winter      Sochi  Ice Hockey
# 17     FIN  1948 Summer  1948  Summer     London  Gymnastics
#
#                                      Event   Medal
# ID
# 4              Tug-Of-War Men's Tug-Of-War    Gold
# 15  Swimming Men's 200 metres Breaststroke  Bronze
# ...

# %%
# Gold Medal Winners since 1896
gold_winners= data2[data2["Medal"]=="Gold"]
gold_winners.head()
# Out:
#                        Name Sex   Age  Height  Weight            Team Country  \
# ID
# 4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden     DEN
# 17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland     FIN
# 17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland     FIN
# 17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland     FIN
# 20       Kjetil Andr Aamodt   M  20.0   176.0    85.0          Norway     NOR
#
#           Games  Year  Season         City          Sport  \
# ID
# 4   1900 Summer  1900  Summer        Paris     Tug-Of-War
# 17  1948 Summer  1948  Summer       London     Gymnastics
# 17  1948 Summer  1948  Summer       London     Gymnastics
# 17  1948 Summer  1948  Summer       London     Gymnastics
# 20  1992 Winter  1992  Winter  Albertville  Alpine Skiing
#
#                                Event Medal
# ID
# 4        Tug-Of-War Men's Tug-Of-War  Gold
# 17  Gymnastics Men's Team All-Around  Gold
# ...

# %%
# Silver Medal Winners since 1896
silver_winners= data2[data2["Medal"]=="Silver"]
silver_winners.head()
# Out:
#                   Name Sex   Age  Height  Weight         Team Country  \
# ID
# 20  Kjetil Andr Aamodt   M  22.0   176.0    85.0       Norway     NOR
# 20  Kjetil Andr Aamodt   M  22.0   176.0    85.0       Norway     NOR
# 25    Alf Lied Aanning   M  24.0     NaN     NaN       Norway     NOR
# 30    Pepijn Aardewijn   M  26.0   189.0    72.0  Netherlands     NED
# 38        Karl Jan Aas   M  20.0     NaN     NaN       Norway     NOR
#
#           Games  Year  Season         City          Sport  \
# ID
# 20  1994 Winter  1994  Winter  Lillehammer  Alpine Skiing
# 20  1994 Winter  1994  Winter  Lillehammer  Alpine Skiing
# 25  1920 Summer  1920  Summer    Antwerpen     Gymnastics
# 30  1996 Summer  1996  Summer      Atlanta         Rowing
# 38  1920 Summer  1920  Summer    Antwerpen     Gymnastics
#
#                                             Event   Medal
# ID
# 20                   Alpine Skiing Men's Downhill  Silver
# 20                   Alpine Skiing Men's Combined  Silver
# ...

# %%
# Bronze Medal Winners since 1896
bronze_winners= data2[data2["Medal"]=="Bronze"]
bronze_winners.head()
# Out:
#                         Name Sex   Age  Height  Weight     Team Country  \
# ID
# 15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN  Finland     FIN
# 15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN  Finland     FIN
# 16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0  Finland     FIN
# 17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland     FIN
# 17   Paavo Johannes Aaltonen   M  32.0   175.0    64.0  Finland     FIN
#
#           Games  Year  Season       City       Sport  \
# ID
# 15  1920 Summer  1920  Summer  Antwerpen    Swimming
# 15  1920 Summer  1920  Summer  Antwerpen    Swimming
# 16  2014 Winter  2014  Winter      Sochi  Ice Hockey
# 17  1948 Summer  1948  Summer     London  Gymnastics
# 17  1952 Summer  1952  Summer   Helsinki  Gymnastics
#
#                                      Event   Medal
# ID
# 15  Swimming Men's 200 metres Breaststroke  Bronze
# 15  Swimming Men's 400 metres Breaststroke  Bronze
# ...

# %%
# Save top 5 medal winners
gwa = gold_winners['Name'].value_counts().sort_values(ascending=True)[-5:]
swa = silver_winners['Name'].value_counts().sort_values(ascending=True)[-5:]
bwa = bronze_winners['Name'].value_counts().sort_values(ascending=True)[-5:]

# %%
# Plotting with Horizontal View
plt.subplots(figsize=(18,24))
ax1 = plt.subplot(311)
gwa.plot.barh(width=.7)
ax2 = plt.subplot(312, sharex=ax1)
swa.plot.barh(width=.7)
ax3 = plt.subplot(313, sharex=ax1)
bwa.plot.barh(width=.7)

ax3.set_xlabel('Medal Count')
ax1.set_ylabel('Athletes')
plt.show()

# %%
# Get Gender Count
sex_cnt= data_summer.groupby(['Year','Sex']).size().reset_index(name='Count')
sex_cnt.head()
# Out:
#    Year Sex  Count
# 0  1896   M    380
# 1  1900   F     33
# 2  1900   M   1903
# 3  1904   F     16
# 4  1904   M   1285

# %%
# Plot Time Series using Seaborn
plt.rcParams["axes.labelsize"] = 20
f, ax_s= plt.subplots(figsize=(25,15))
#sns.set_context("notebook", font_scale=0.5, rc={"font.size":8,"axes.labelsize":5})

ax_s.set_title("Gender Participation in Summer Olympics",fontsize=20)

sns.pointplot(x="Year", y="Count", hue="Sex", data=sex_cnt, ax= ax_s)
plt.show()

# %%
# Gender count in Winter Olympic
sex_cntw= data_winter.groupby(['Year','Sex']).size().reset_index(name='Count')
sex_cntw.head()
# Out:
#    Year Sex  Count
# 0  1924   F     17
# 1  1924   M    443
# 2  1928   F     33
# 3  1928   M    549
# 4  1932   F     22

# %%
plt.rcParams["axes.labelsize"] = 20
f, ax_s= plt.subplots(figsize=(25,15))
#sns.set_context("notebook", font_scale=0.5, rc={"font.size":8,"axes.labelsize":5})

ax_s.set_title("Gender Participation in Winter Olympics",fontsize=20)

sns.pointplot(x="Year", y="Count", hue="Sex", data=sex_cntw, ax= ax_s)
plt.show()

# %%
x.count()
# Out:
# Name      208241
# Sex       208241
# Age       207379
# Height    206853
# Weight    208241
# Team      208241
# NOC       208241
# Games     208241
# Year      208241
# Season    208241
# City      208241
# Sport     208241
# Event     208241
# Medal      30456
# dtype: int64

# %% [markdown]
# ## Cleaning

# %%
athlete_data["NOC"].value_counts()
# Out:
# USA    18853
# FRA    12758
# GBR    12256
# ITA    10715
# GER     9830
# CAN     9733
# JPN     8444
# SWE     8339
# AUS     7638
# HUN     6607
# POL     6207
# SUI     6150
# NED     5839
# URS     5685
# FIN     5467
# ESP     5313
# RUS     5143
# AUT     5141
# CHN     5141
# NOR     4960
# KOR     4464
# ROU     4405
# TCH     4404
# BEL     3857
# BRA     3848
# DEN     3570
# BUL     3530
# FRG     3315
# ARG     3297
# GRE     3181
#        ...
# SOM       32
# YEM       32
# MTN       29
# LCA       28
# SOL       27
# FSM       26
# PLW       25
# PLE       21
# GBS       21
# WIF       20
# COM       19
# DMA       19
# CPV       18
# STP       15
# MHL       14
# NRU       13
# RHO       12
# ROT       12
# CRT       11
# YAR       11
# KIR       11
# BRU       10
# TLS        9
# KOS        8
# TUV        7
# YMD        5
# SSD        3
# NBO        2
# UNK        2
# NFL        1
# Name: NOC, Length: 230, dtype: int64

# %%
athlete_data["Season"].value_counts()
# Out:
# Summer    222552
# Winter     48564
# Name: Season, dtype: int64

# %%
athlete_data.count()
# Out:
# Name      271116
# Sex       271116
# Age       261642
# Height    210945
# Weight    208241
# Team      271116
# NOC       271116
# Games     271116
# Year      271116
# Season    271116
# City      271116
# Sport     271116
# Event     271116
# Medal      39783
# dtype: int64

# %%
athlete_data.dtypes
# Out:
# Name       object
# Sex        object
# Age       float64
# Height    float64
# Weight    float64
# Team       object
# NOC        object
# Games      object
# Year        int64
# Season     object
# City       object
# Sport      object
# Event      object
# Medal      object
# dtype: object

# %%
athlete_data = athlete_data.rename({'NOC': 'Country'}, axis=1)

# %%
athlete_data.head()
# Out:
#                         Name Sex   Age  Height  Weight            Team  \
# ID
# 1                  A Dijiang   M  24.0   180.0    80.0           China
# 2                   A Lamusi   M  23.0   170.0    60.0           China
# 3        Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 4       Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 5   Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    Country        Games  Year  Season       City          Sport  \
# ID
# 1      CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 2      CHN  2012 Summer  2012  Summer     London           Judo
# 3      DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 4      DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 5      NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                                Event Medal
# ID
# 1        Basketball Men's Basketball   NaN
# 2       Judo Men's Extra-Lightweight   NaN
# ...

# %%
athlete_data.describe()
# Out:
#                  Age         Height         Weight           Year
# count  261642.000000  210945.000000  208241.000000  271116.000000
# mean       25.556898     175.338970      70.702393    1978.378480
# std         6.393561      10.518462      14.348020      29.877632
# min        10.000000     127.000000      25.000000    1896.000000
# 25%        21.000000     168.000000      60.000000    1960.000000
# 50%        24.000000     175.000000      70.000000    1988.000000
# 75%        28.000000     183.000000      79.000000    2002.000000
# max        97.000000     226.000000     214.000000    2016.000000

# %%
#Filtering Data for certain sports
data_basketball=x[x.Sport=='Basketball']


#Medalists
medalists = x[x.Medal.notnull()]


#Gold medalists
winners=x[x.Medal=='Gold']
#winners.head()
#medalists.head()
data_basketball.head()
# Out:
#                                    Name Sex   Age  Height  Weight   Team  NOC  \
# ID
# 1                             A Dijiang   M  24.0   180.0    80.0  China  CHN
# 69                    Tamara Abalde Daz   F  19.0   185.0    72.0  Spain  ESP
# 136                    Alessandro Abbio   M  29.0   195.0    85.0  Italy  ITA
# 192  Ahmed El-Sayed Abdel Hamid Mobarak   M  25.0   189.0    85.0  Egypt  EGY
# 199                   Amir Abdel Meguid   M  23.0   178.0    67.0  Egypt  EGY
#
#            Games  Year  Season         City       Sport  \
# ID
# 1    1992 Summer  1992  Summer    Barcelona  Basketball
# 69   2008 Summer  2008  Summer      Beijing  Basketball
# 136  2000 Summer  2000  Summer       Sydney  Basketball
# 192  1972 Summer  1972  Summer       Munich  Basketball
# 199  1984 Summer  1984  Summer  Los Angeles  Basketball
#
#                              Event Medal
# ID
# 1      Basketball Men's Basketball   NaN
# 69   Basketball Women's Basketball   NaN
# ...

# %%
basketball_winners=winners[winners.Sport=='Basketball']

sns.countplot(x="Team", data=basketball_winners) #Disparity in number of Basketball Gold medal winners

# %%
usa_medalists=medalists[medalists.Team=='United States']
usa_medalists.head()

sns.countplot(x="Medal", data=usa_medalists) #Number of USA Gold medal winners (Including team sports)

# %% [markdown]
# ## Questions and Plots

# %%
x = sns.stripplot(x="Sex", y="Age", hue="Medal",
...                    data=medalists, jitter=True)

# %%
sns.lmplot(x='Weight', y='Age', data= x)
# Out:
# /usr/local/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
men = (x.Sex == 'M')
women = (x.Sex == 'W')

with sns.axes_style(style=None):
    sns.violinplot("Sex", "Age", hue="Sex", data= x,
                   split=True, inner="quartile",
                   palette=["red", "green"]);

# %%
sns.violinplot("Sex", "Weight", data= x,
               palette=["lightblue", "lightpink"]);
# Out:
# /usr/local/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
with sns.axes_style('darkgrid'):
    g = sns.factorplot("Year", data= x, aspect=4.0, kind='count',
                       hue='Sex', order=range(2000, 2016))

g.set_ylabels('Total Olympians')
# Out:
# /usr/local/lib/python3.6/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
with sns.axes_style('darkgrid'):
    g = sns.factorplot("Year", data= x, aspect=4.0, kind='count',
                       hue='Medal', order=range(1910, 1950))

g.set_ylabels('Medal')
# Out:
# /usr/local/lib/python3.6/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.lmplot(x='Year', y='Age', data= x)
# Out:
# /usr/local/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Set theme
sns.set_style('whitegrid')
 
# Violin plot
sns.violinplot(x='Weight', y='Age', data= x)
# Out:
# /usr/local/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
